# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
IA = cv2.imread('IMG_A.png')
IB = cv2.imread('IMG_B.png')

[r,c] = IA.shape()
[r,c]

# %%
x=20
y=30

x2=21
y2=30

w2=2
h2=2

v1=IA[(y1-h2):(y1+h2+1),(x1-w2):(x1+w2+1)]
v2=IA[(y2-h2):(y2+h2+1),(x2-w2):(x2+w2+1)]

print(v1)
print(v2)
